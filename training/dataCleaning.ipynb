# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## **Import package**

# %%
import pandas as pd
import numpy as np
import re
# from symspellpy import SymSpell, Verbosity
from collections import Counter
# from underthesea import word_tokenize
import json
from google.colab import drive
from difflib import get_close_matches

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Read data**

# %%
df = pd.read_json(
    "/content/drive/MyDrive/statlearning/ner_labeled_data_full.jsonl",
    lines=True,
    encoding="utf-8"
)

# %%
df.head()
# Out:
#                                                 text  \
# 0  Con gái bầu Đức gom bất thành 4 triệu cp HAG v...
# 1  HOSE tháng 4: Hầu hết chỉ số ngành giảm điểm, ...
# 2  Đầu tư Phát triển Mỹ Khánh tất toán trước hạn ...
# 3  Thanh khoản UPC oM tăng 13% trong tháng 4.Thị ...
# 4  Thị trường chứng quyền tuần 19-23/05/2025: Sắc...
#
#                                             entities  \
# 0  [{'text': 'HAG', 'type': 'STOCK', 'start': 36,...
# 1  [{'text': 'HOSE', 'type': 'STOCK', 'start': 0,...
# 2  [{'text': '2.2 ngàn tỷ', 'type': 'NUM', 'start...
# 3  [{'text': 'tăng 13%', 'type': 'NUM', 'start': ...
# 4  [{'text': 'SSI', 'type': 'STOCK', 'start': 291...
#
#                                               source
# 0  https://vietstock.vn/2025/05/con-gai-bau-duc-g...
# 1  https://vietstock.vn/2025/05/hose-thang-4-hau-...
# 2  https://vietstock.vn/2025/05/dau-tu-phat-trien...
# 3  https://vietstock.vn/2025/05/thanh-khoan-upcom...
# 4  https://vietstock.vn/2025/05/thi-truong-chung-...

# %%
stock_list = []
with open("/content/drive/MyDrive/statlearning/all_vn_stock_codes.txt", "r", encoding="utf-8") as f:
    stock_list = [line.strip().upper() for line in f if line.strip()]

# %%
def build_common_company_names(df, top_n=500):
    company_names = []
    for entities in df["entities"]:
        for ent in entities:
            if ent["type"] == "COMPANY":
                company_names.append(ent["text"].strip())
    most_common = Counter(company_names).most_common(top_n)
    return [name for name, _ in most_common]

# %%
company_list = build_common_company_names(df)

# %%
company_list
# Out:
# ['Fed',
#  'UBCKNN',
#  'NHNN',
#  'CTCK',
#  'KBSV',
#  'VNDIRECT',
#  'Dragon Capital',
#  'ACBS',
#  'Aseansc',
#  'VCBS',
#  'VietinBank',
#  'Bộ Tài chính',
#  'BSC',
#  'DNSE',
#  'MSCI',
#  'Vingroup',
#  'Yuanta',
#  'KIS',
#  'Vietcap',
#  'VinaCapital',
#  'Vietcombank',
#  'FTSE Russell',
#  'FTSE',
#  'SCIC',
#  'VDSC',
#  'SSV',
#  'VSDC',
#  'Vinamilk',
#  'PYN Elite',
#  'Masan',
#  'Vietstock',
#  'Novaland',
#  'PAN',
#  'BIDV',
#  'UOB',
#  'Masan Consumer',
#  'Pomina',
#  'Ủy ban Chứng khoán Nhà nước',
#  'Berkshire Hathaway',
#  'SSIR',
#  'HAGL',
#  'SJC',
#  'IFC',
#  'TPS',
#  'DAS',
#  'VNG',
#  'Apple',
#  'Coteccons',
#  'FPTS',
#  'Agriseco Research',
#  'Ngân hàng Nhà nước',
#  'F88',
#  'SK Group',
#  'Novagroup',
#  'Vinhomes',
#  'CTCK BIDV',
#  'Sacombank',
#  'CTCK KB Việt Nam',
#  'HDI Global SE',
#  'FLC',
#  'SSIAM',
#  'VietstockFinance',
#  'HSC',
#  'BETA',
#  'Vinatex',
#  'Mirae Asset',
#  'Beta',
#  'Hòa Phát',
#  'CTCK Asean',
#  'SSI Research',
#  'Vinpearl',
#  'YSVN',
#  'Berkshire',
#  'BlackRock',
#  'EVN',
#  'FDI',
#  'Hải An',
#  'SSI',
#  'CTCK Tiên Phong',
#  'Nam Long',
#  'CTCP',
#  'Asean',
#  'HĐQT',
#  'WCM',
#  'VNDIRECT Research',
#  'Sabeco',
#  'MB',
#  'Vinalines',
#  'SHS',
#  'NHSV',
#  'Tập đoàn Masan',
#  'Nvidia',
#  'Masan Group',
#  'Faros',
#  'BVSC',
#  'Công ty Điện lực An Phú Đông',
#  'PYN Elite Fund',
#  'Viconship',
#  'Hưng Thịnh Land',
#  'KIM',
#  'VPS',
#  'ASKA',
#  'VPB ankS',
#  'Ngân hàng Nhà nước Việt Nam',
#  'Huatai',
#  'ngân hàng',
#  'Đất Xanh',
#  'Agribank',
#  'Sở Giao dịch Chứng khoán TPHCM',
#  'CTCK Yuanta Việt Nam',
#  'SCB',
#  'WinCommerce',
#  'Yuanta Việt Nam',
#  'AASC',
#  'Công ty Phát Đạt',
#  'NHTW',
#  'Techcombank',
#  'CTCK BETA',
#  'City Auto',
#  'UBCK',
#  'HDC',
#  'Bamboo Capital',
#  'VCBF',
#  'ECB',
#  'VNPT',
#  'ZaloPay',
#  'HSBC',
#  'Lộc Trời',
#  'VinFast',
#  'chứng khoán',
#  'CTCK Sài Gòn - Hà Nội',
#  'PVN',
#  'Vietnam Airlines',
#  'VIS Rating',
#  'CTCK Đông Á',
#  'Chat GPT',
#  'Sở Giao dịch Chứng khoán Hà Nội',
#  'ABSR',
#  'Đầu tư TTC',
#  'Thiên Nam Group',
#  'Bộ Kế hoạch và Đầu tư',
#  'Agriseco',
#  'BĐS',
#  'CTCP Tập đoàn Đất Xanh',
#  'KB',
#  'TCSC',
#  'CTCK Vietcombank',
#  'bất động sản',
#  'TTCK',
#  'FPT',
#  'FOMC',
#  'EVNHCMC',
#  'Norges Bank',
#  'VNSC',
#  'VietinBank Capital',
#  'VPB',
#  'CTCK Beta',
#  'TCBS',
#  'MSVN',
#  'CTCK Vietcap',
#  'Công ty',
#  'CEE',
#  'BIM Land',
#  'KISV',
#  'CTCP Hoàng Anh Gia Lai',
#  'Research',
#  'VBMA',
#  'CTCK Phú Hưng',
#  'Chính phủ',
#  'Cen Land',
#  'MMC',
#  'Đông Á',
#  'CHIN-SU',
#  'Bộ Công Thương',
#  'CTCK Shinhan Việt Nam',
#  'Gemadept',
#  'Dabaco',
#  'Tổng công ty lưu ký và bù trừ chứng khoán Việt Nam',
#  'Hanosimex',
#  'Facebook',
#  'Tập đoàn Hưng Thịnh',
#  'Fubon ETF',
#  'VND irect',
#  'Amazon',
#  'VCAM',
#  'VSD',
#  'Khang Điền',
#  'OPEC+',
#  'Bộ Công an',
#  'Zalo',
#  'Eximbank',
#  'No Va Thảo Điền',
#  'IB',
#  'CTCP Tập đoàn Đầu tư Địa ốc No Va',
#  'Hà An',
#  'Vinacomin',
#  'Thaco',
#  'VNDirect',
#  'SeABank',
#  'KB Việt Nam',
#  'Nam A Bank',
#  'Bloomberg',
#  'Vincom Retail',
#  'Tổng Công ty Lưu ký và Bù trừ Chứng khoán Việt Nam',
#  'CTCK Rồng Việt',
#  'CTCP Chứng khoán VNDIRECT',
#  'CASC',
#  'IR',
#  'WB',
#  'Finhay',
#  'Maybank',
#  'T&T',
#  'JICA',
#  'Bách Hóa Xanh',
#  'TikTok',
#  'Vietnam Enterprise Investments Limited',
#  'MBS',
#  'Cục Dự trữ Liên bang Mỹ',
#  'Tiên Phong',
#  'ABS',
#  'i KIS',
#  'doanh nghiệp',
#  'APG',
#  'iShares ETF',
#  'Hoà Phát',
#  'Haxaco',
#  'VINGROUP',
#  'VAFE',
#  'Ngân hàng TMCP Quân Đội',
#  'FTSE ETF',
#  'DICC orp',
#  'VDSC Research',
#  'Amersham Industries Limited',
#  'Bất động sản Hà An',
#  'APEC',
#  'Viettel',
#  'KIM VN',
#  'CTCP Tập đoàn Xây dựng Hòa Bình',
#  'Microsoft',
#  'NCB',
#  'BHX',
#  'Tesla',
#  'Golden Hill Invest',
#  'CTCP Chứng khoán APG',
#  'OpenAI',
#  'SBV',
#  'VietinbankCapital',
#  'PVcomBank',
#  'CTCK Agribank',
#  'PHS',
#  'SGIC apital',
#  'J.P Morgan',
#  'Alibaba',
#  'TCAM',
#  'UBOT',
#  'VanEck Vectors Vietnam ETF',
#  'CTCP Southgate',
#  'DIC Corp',
#  'GELEX',
#  'Fitch',
#  'KB Buddy',
#  'CTCP Thương mại Xuất nhập khẩu Thiên Nam',
#  'CTCP Vạn Đạt Group',
#  'CTCP Hồng Lam Xuân Thành',
#  'CTCP Chứng khoán BETA',
#  'VII',
#  'SMC',
#  'Sài Gòn Capital',
#  'CTCP Dược Hậu Giang',
#  'KIM Việt Nam',
#  'Samsung',
#  'CTCK Sài Gòn – Hà Nội',
#  'Hanoi Investments Holdings Limited',
#  'Vinaconex',
#  'CTCK Thiên Việt',
#  'Evergrande',
#  'Nam Ngư',
#  'Taseco Land',
#  'IDICO',
#  'Goldman Sachs',
#  'CTCP Đầu tư Nam Long',
#  'BKAV Pro',
#  'Fideco',
#  'Morgan Stanley',
#  'Vinasun',
#  'irect',
#  'CTCP Vinhomes',
#  'An Gia',
#  'PVI',
#  'Mekolor',
#  'TVSI',
#  'TPSR',
#  'Hoàng Anh Gia Lai',
#  'FECON',
#  'Vinacontrol',
#  'CADIVI',
#  'BoC',
#  'Rồng Việt',
#  'METCO',
#  'LDG',
#  'Imexpharm',
#  'Vinaship',
#  'CC1-Holdings',
#  'ADB',
#  'HUSK',
#  'SGI Capital',
#  'Alpha King',
#  'Google',
#  'Vạn Thịnh Phát',
#  'Hado Charm Villas',
#  'Union Bank of Taiwan',
#  'Chứng khoán Mirae Asset',
#  'iPhone',
#  'Chứng khoánAPG',
#  'TSMC',
#  'Fahasa',
#  'Aqua City',
#  'Chứng khoán KIS',
#  'Shopee',
#  'CTCP Sữa Việt Nam',
#  'iShares',
#  'GEM',
#  'Moody’s',
#  'GC Food',
#  'VFS',
#  'UHY',
#  'BoE',
#  'CTCP Container Việt Nam',
#  'VICEM',
#  'VISR',
#  'HELIOS',
#  'Kido',
#  'DN',
#  'Bộ Thông tin và Truyền thông',
#  'Ngân hàng TMCP Á Châu',
#  'Bank of America',
#  'FSN Asia',
#  'Công ty Faros',
#  'Phát Đạt',
#  'CII',
#  'CTCP Hưng Thịnh Incons',
#  'CTCP Xuất Nhập khẩu An Giang',
#  'CTCP Xây dựng Coteccons',
#  'KBSV Research',
#  'CTCP Tập đoàn Lộc Trời',
#  'CTCP Bảo hiểm Viễn Đông',
#  'KVGF',
#  'Rạng Đông',
#  'CTCKBSC',
#  'CIII',
#  'Cục Dự trữ Liên bang Mỹ (Fed)',
#  'PwC',
#  'Petrolimex',
#  'Bộ Tư pháp',
#  'Quốc hội',
#  'NTS',
#  'Âu Lạc',
#  'ManulifeIM',
#  'Chứng khoán KB Việt Nam',
#  'VISR ating',
#  'CTCK VND irect',
#  'Ricons',
#  'CTCK BIDV (BSC)',
#  'Sài Gòn – Hà Nội',
#  'MYA Capital',
#  'BIDVT',
#  'CTCP Thép Pomina',
#  'SK',
#  'CTCP Vận tải và Xếp dỡ Hải An',
#  'VietCapital',
#  'Sài Gòn - Hà Nội',
#  'VCSC',
#  'Vietnam Enterprise Investment Limited',
#  'Wareham Group Limited',
#  'Chứng khoánVPS',
#  'Công ty TNHH Điện lực Sông Hậu 2',
#  'CTCP Tập đoàn FLC',
#  'Fubon',
#  'CTCP Nông nghiệp Quốc tế Hoàng Anh Gia Lai',
#  'CTCKBIDV',
#  'CTCP Bất động sản Thế Kỷ',
#  'Vinam',
#  'CTCP Vinpearl',
#  'Tổng công ty Lưu ký và Bù trừ chứng khoán Việt Nam',
#  'Hội An Invest',
#  'Veil Holding Limited',
#  'CTCP Thành Thành Công - Biên Hòa',
#  'CTCP Syrena',
#  'Talanx',
#  'CTCP Kinh doanh F88',
#  'Ngân hàng',
#  'Hoa Sen',
#  'Intel',
#  'VanEck',
#  'CTCP Hưng Thịnh Land',
#  'NVIDIA',
#  'CTCP Đông Hải Bến Tre',
#  'MarketVector Vietnam Local Index',
#  'SP Group',
#  'CTCP Sài Gòn Capital',
#  'Hưng Thịnh Corp',
#  'Tập đoàn Hoa Sen',
#  'Vietinbank',
#  'Trung tâm lưu ký Chứng khoán Việt Nam',
#  'CTCP Năng lượng Tái tạo Trung Nam',
#  'TVS',
#  'Vietstock LIVE',
#  'NH',
#  'Vũng Áng 1',
#  'Thiên Việt',
#  'VSIP',
#  'Qualcomm',
#  'ETF',
#  'An Khang',
#  'Công ty TNHH Thành phố Aqua',
#  'VPB ank',
#  'H.C. Starck',
#  'HĐ QT',
#  'ABSR esearch',
#  'CTCP Tập đoàn Dabaco Việt Nam',
#  'Nhựa Việt Thành',
#  'Công ty TNHH Đầu tư và Phát triển Bất động sản Phát Đạt',
#  'Grab',
#  'CTCK VPB ank',
#  'VNECO',
#  'Internation Finance Corporation',
#  'Shinhan Việt Nam',
#  'Chứng khoán DNSE',
#  'SSIResearch',
#  'CTCP Minh Khang Capital Trading Public',
#  'MAS',
#  'bán lẻ',
#  'VDS',
#  'ngành ngân hàng',
#  'IMF',
#  'CTCP Dệt may Liên Phương',
#  'Westgate',
#  'Rạng Đông Holding',
#  'Bách hóa Xanh',
#  'CTCP Tư vấn Xây dựng Điện 2',
#  'Tổng CTCP Bia - Rượu - Nước giải khát Sài Gòn',
#  'IUH',
#  'CTCP Hưng Thịnh Investment',
#  'CTCK Tiên Phong (TPS)',
#  'FPTC',
#  'SSIR esearch',
#  'Techcom Capital',
#  'Mirae Asset Việt Nam',
#  'May Sông Hồng',
#  'WHO',
#  'Tiger Global',
#  'TTCG roup',
#  'Goldsun',
#  'ankS',
#  'Angimex',
#  'Lazada',
#  'Sở Giao dịch Chứng khoán TP.HCM',
#  'CTCP Đầu tư Thế giới Di động',
#  'CTCP Tập đoàn Hưng Thịnh',
#  'Greenfeed',
#  'Huawei',
#  'Tập đoàn Đầu tư Địa ốc No Va',
#  'Chứng khoán Rồng Việt',
#  'Masan Horizon',
#  'VPBank',
#  'CTCP PVI',
#  'Keppel Land',
#  'Flemmington Investments Pte Ltd',
#  'LPBank',
#  'Ủy ban Thị trường Mở Liên bang',
#  'IBSSI',
#  'CTCP Chứng khoán Thủ Đô',
#  'BIG',
#  'CTCP Đường Quảng Ngãi',
#  'MHT',
#  'Fmarket',
#  'Lasuco',
#  'DICC',
#  'Nova Hospitality',
#  'CTCP Đầu tư và Kinh doanh Nhà Khang Điền',
#  'VEAM',
#  'American Express',
#  'Yeah1',
#  'Becamex IDC',
#  'CTCP Tập đoàn Hòa Phát',
#  'Munich Re',
#  'Chứng khoán HSC',
#  'CTCP Thương mại Đầu tư Dầu khí Nam Sông Hậu',
#  'Tập đoàn Vingroup',
#  'Camimex Group',
#  'Golden Hill',
#  'BSC Research',
#  'Korea Investment Management',
#  'CTCP Tập đoàn Bamboo Capital',
#  'CTCKSSI',
#  'Domesco',
#  'FED',
#  'CTCK Shinhan',
#  'LinkedIn',
#  'Petrosetco']

# %%
def safe_get_span(text, value):
    try:
        start = text.index(value)
        end = start + len(value)
        return start, end
    except ValueError:
        return -1, -1

# %%
def clean_entities_and_text(text, entities, stock_list, company_list, cutoff=0.8):
    new_text = text
    temp_entities = []

    offset = 0  # Để tính sự thay đổi độ dài sau khi thay thế từ

    for ent in entities:
        ent_text = ent["text"]
        ent_type = ent["type"]
        ent_start = ent.get("start")
        ent_end = ent.get("end")

        if ent_start is None or ent_end is None:
            ent_start, ent_end = safe_get_span(new_text, ent_text)
            if ent_start == -1:
                temp_entities.append(ent)
                continue  # Không tìm thấy thì bỏ qua xử lý sửa

        # Lấy đoạn gốc trong text hiện tại
        current_text = new_text[ent_start + offset: ent_end + offset]

        if ent_type == "STOCK":
            corrected = ent_text.upper()
            if corrected in stock_list:
                # Thay đúng vị trí trong text
                new_text = new_text[:ent_start + offset] + corrected + new_text[ent_end + offset:]
                delta = len(corrected) - (ent_end - ent_start)
                temp_entities.append({
                    "text": corrected,
                    "type": ent_type,
                    "start": ent_start + offset,
                    "end": ent_start + offset + len(corrected)
                })
                offset += delta
            else:
                # Giữ nguyên nhưng vẫn gán lại vị trí
                temp_entities.append({
                    "text": ent_text,
                    "type": ent_type,
                    "start": ent_start + offset,
                    "end": ent_end + offset
                })

        elif ent_type == "COMPANY":
            matched = get_close_matches(ent_text, company_list, n=1, cutoff=cutoff)
            corrected = matched[0] if matched else ent_text
            new_text = new_text[:ent_start + offset] + corrected + new_text[ent_end + offset:]
            delta = len(corrected) - (ent_end - ent_start)
            temp_entities.append({
                "text": corrected,
                "type": ent_type,
                "start": ent_start + offset,
                "end": ent_start + offset + len(corrected)
            })
            offset += delta

        else:
            # Giữ nguyên hoàn toàn cho các loại khác
            temp_entities.append({
                "text": ent_text,
                "type": ent_type,
                "start": ent_start + offset,
                "end": ent_end + offset
            })

    return new_text, temp_entities

# %%
for i in range(len(df)):
    raw_text = df.at[i, "text"]
    raw_ents = df.at[i, "entities"]

    new_text, new_ents = clean_entities_and_text(raw_text, raw_ents, stock_list, company_list)

    # Ghi đè vào chính cột gốc
    df.at[i, "text"] = new_text
    df.at[i, "entities"] = new_ents

# %%
df.head()
# Out:
#                                                 text  \
# 0  Con gái bầu Đức gom bất thành 4 triệHAGp HAG v...
# 1  HOSE tháng 4: Hầu hết chỉ số ngành giảm điểm, ...
# 2  Đầu tư Phát triển Mỹ Khánh tất toán trước hạn ...
# 3  Thanh khoản UPC oM tăng 13% trong tháng 4.Thị ...
# 4  Thị trường chứng quyền tuần 19-23/05/2025: Sắc...
#
#                                             entities  \
# 0  [{'text': 'HAG', 'type': 'STOCK', 'start': 36,...
# 1  [{'text': 'HOSE', 'type': 'STOCK', 'start': 0,...
# 2  [{'text': '2.2 ngàn tỷ', 'type': 'NUM', 'start...
# 3  [{'text': 'tăng 13%', 'type': 'NUM', 'start': ...
# 4  [{'text': 'SSI', 'type': 'STOCK', 'start': 291...
#
#                                               source
# 0  https://vietstock.vn/2025/05/con-gai-bau-duc-g...
# 1  https://vietstock.vn/2025/05/hose-thang-4-hau-...
# 2  https://vietstock.vn/2025/05/dau-tu-phat-trien...
# 3  https://vietstock.vn/2025/05/thanh-khoan-upcom...
# 4  https://vietstock.vn/2025/05/thi-truong-chung-...

# %%
# import json

with open("/content/drive/MyDrive/statlearning/cleaned_data_full.jsonl", "w", encoding="utf-8") as f:
    for _, row in df.iterrows():
        json.dump({
            "text": row["text"],
            "entities": row["entities"],
            "source" : row['source']
        }, f, ensure_ascii=False)
        f.write("\n")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-21-3117440784.py in <cell line: 0>()
#       1 # import json
#       2
# ----> 3 with open("/content/drive/MyDrive/statlearning/cleaned_data_full.jsonl", "w", encoding="utf-8") as f:
#       4     for _, row in df.iterrows():
#       5         json.dump({
#
# OSError: [Errno 30] Read-only file system: '/content/drive/MyDrive/statlearning/cleaned_data_full.jsonl'
